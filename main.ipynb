# %%
import main
# Out:
# Path to PlantVillage dataset files: /Users/nd2204/.cache/kagglehub/datasets/emmarex/plantdisease/versions/1
# 🚀 Starting Plant Disease Detection Pipeline...
# ...
#
# 📁 PHASE 1: Data Collection
# ------------------------------
# Scanning dataset directory structure...
# Reading classes: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 97.19it/s]
# ✅ Found 20654 images across 16 classes
#
# 🔍 PHASE 2: Feature Extraction
# ------------------------------
# Extracting features from images...
# Processing images: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20654/20654 [01:10<00:00, 292.82it/s]
# ✅ Successfully processed 20638 images
# ⚠️  Failed to process 16 images (will be skipped)
# 📊 Feature matrix shape: (20638, 8868)
#
# ⚙️  PHASE 3: Data Preprocessing
# ...
